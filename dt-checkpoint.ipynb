# %%
import pandas as pd
loans=pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-2/master/Data/loan_data.csv')

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loans.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
loans.shape
# Out:
# (9578, 14)

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.corr()
# Out:
#                    credit.policy  int.rate  installment  log.annual.inc  \
# credit.policy           1.000000 -0.294089     0.058770        0.034906
# int.rate               -0.294089  1.000000     0.276140        0.056383
# installment             0.058770  0.276140     1.000000        0.448102
# log.annual.inc          0.034906  0.056383     0.448102        1.000000
# dti                    -0.090901  0.220006     0.050202       -0.054065
# fico                    0.348319 -0.714821     0.086039        0.114576
# days.with.cr.line       0.099026 -0.124022     0.183297        0.336896
# revol.bal              -0.187518  0.092527     0.233625        0.372140
# revol.util             -0.104095  0.464837     0.081356        0.054881
# inq.last.6mths         -0.535511  0.202780    -0.010419        0.029171
# delinq.2yrs            -0.076318  0.156079    -0.004368        0.029203
# pub.rec                -0.054243  0.098162    -0.032760        0.016506
# ...

# %%
def tree():
    return loans.isnull().sum()

# %%
#above mentioned function will display all null datasets
tree()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
def tree():
    plt.figure(figsize=(10,6))
    loans[loans['credit.policy']==1]['fico'].hist(alpha=0.5,color='blue',bins=30,label='Credit.Policy=1')
    loans[loans['credit.policy']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='Credit.Policy=0')
    plt.legend()
    plt.xlabel('FICO')
tree()

# %%
#paid vs not fully paid in a histogram
import matplotlib.pyplot as plt
def tree():
    plt.figure(figsize=(10,6))
    loans[loans['not.fully.paid']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='not.fully.paid=1')
    loans[loans['not.fully.paid']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='not.fully.paid=0')
    plt.legend()
    plt.xlabel('FICO')
tree()

# %%
#not fully paid vs reason of not paying
import seaborn as sns
def tree():
    plt.figure(figsize=(11,7))
    sns.countplot(x='purpose',hue='not.fully.paid',data=loans,palette='Set1')
tree()

# %%
import seaborn as sns
def tree():
    plt.figure(figsize=(11,7))
    sns.countplot(x='purpose', hue='not.fully.paid',data = loans, palette = 'Set1')
tree()

# %%
cat_feats = ['purpose']

# %%
final_data= pd.DataFrame()
def tree():
    final_data = pd.get_dummies(loans, columns = cat_feats, drop_first = True )
    return final_data
final_data=tree()

# %%
#create a function to extract the independent column into X
X = pd.DataFrame()
def tree():
    X= final_data.drop('not.fully.paid' , axis = 1)
    return X
X = tree()

# %%
#Create a function to extract the y variable as a dependant column
y = pd.DataFrame()
def tree():
    y = final_data.loc[:,final_data.columns == 'not.fully.paid']
    return y
y=tree()

# %%
from sklearn.model_selection import train_test_split
def tree():
    return train_test_split(X,y,test_size=0.30,random_state=101)
X_train,X_test,y_train,y_test = tree()

# %%
def tree():
    print(X_train.shape)
    print(y_train.shape)
tree()
# Out:
# (6704, 18)
# (6704, 1)

# %%
def tree():
    print(X_test.shape)
    print(y_test.shape)
tree()
# Out:
# (2874, 18)
# (2874, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
def tree():
    dtree = DecisionTreeClassifier()
    return dtree
dtree = tree()

# %%
def tree():
    return dtree.fit(X_train,y_train)
tree()
# Out:
# DecisionTreeClassifier()

# %%
predictions = pd.DataFrame()
def tree():
    predictions = dtree.predict(X_test)
    return predictions
predictions = tree()

# %%
from sklearn.metrics import confusion_matrix
def tree():
    print(confusion_matrix(y_test,predictions))
tree()
# Out:
# [[2002  429]
#  [ 334  109]]

# %%
predictions=pd.DataFrame()
def tree():
    predictions = dtree.predict(X_test)
    return predictions
predictions = tree()

# %%
from sklearn.metrics import confusion_matrix
def tree():
    print(confusion_matrix(y_test,predictions))
tree()
# Out:
# [[2002  429]
#  [ 334  109]]

# %%
from sklearn.metrics import recall_score
def log():
    recall1=recall_score(y_test, predictions)
    print('The recall score is :',recall1)
    return recall1
return1 = log()
# Out:
# The recall score is : 0.24604966139954854

# %%
from sklearn.metrics import classification_report
def tree():
    print(classification_report(y_test, predictions))
tree()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      2431
#            1       0.20      0.25      0.22       443
#
#     accuracy                           0.73      2874
#    macro avg       0.53      0.53      0.53      2874
# weighted avg       0.76      0.73      0.74      2874

# %%
def tree():
    difference = recall1 - recall2
    return difference
log()
# Out:
# The recall score is : 0.24604966139954854
# 0.24604966139954854

# %%
from sklearn.tree import plot_tree
plot_tree (dtree, filled = True)
# Out:
# [Text(128.0863279473509, 213.55714285714285, 'X[0] <= 0.5\ngini = 0.272\nsamples = 6704\nvalue = [5614, 1090]'),
#  Text(59.274257731288984, 205.79142857142858, 'X[2] <= 349.935\ngini = 0.408\nsamples = 1317\nvalue = [941, 376]'),
#  Text(45.4584426975052, 198.0257142857143, 'X[9] <= 6.5\ngini = 0.378\nsamples = 943\nvalue = [704, 239]'),
#  Text(33.71189579002079, 190.26, 'X[1] <= 0.084\ngini = 0.36\nsamples = 815\nvalue = [623, 192]'),
#  Text(33.299421777546776, 182.4942857142857, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(34.124369802494805, 182.4942857142857, 'X[17] <= 0.5\ngini = 0.368\nsamples = 789\nvalue = [597, 192]'),
#  Text(22.15476871101871, 174.72857142857143, 'X[8] <= 50.95\ngini = 0.362\nsamples = 768\nvalue = [586, 182]'),
#  Text(6.374012474012474, 166.96285714285713, 'X[8] <= 1.35\ngini = 0.313\nsamples = 329\nvalue = [265, 64]'),
#  Text(2.474844074844075, 159.19714285714286, 'X[4] <= 6.54\ngini = 0.47\nsamples = 37\nvalue = [23, 14]'),
# ...

# %%
from sklearn.tree import export_text
text_representation = export_text(dtree)
print(text_representation)
# Out:
# |--- feature_0 <= 0.50
# |   |--- feature_2 <= 349.93
# |   |   |--- feature_9 <= 6.50
# |   |   |   |--- feature_1 <= 0.08
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  0.08
# |   |   |   |   |--- feature_17 <= 0.50
# |   |   |   |   |   |--- feature_8 <= 50.95
# |   |   |   |   |   |   |--- feature_8 <= 1.35
# |   |   |   |   |   |   |   |--- feature_4 <= 6.54
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1890.02
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  4.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_6 >  1890.02
# ...
